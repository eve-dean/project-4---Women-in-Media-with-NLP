# %% [markdown]
# #Project 4: Natural Language Processing & New York Times Data
# Eve Dean

# %% [markdown]
# ##Notebook Outline:
# The purpose of this notebook is to subset the original data into a useable chunks for preprocessing and NLP. Data is also grouped by decade with 1000 rows selected per decade.

# %% [markdown]
# ##Imports

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Load data & remove NA

# %%
df = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/Project 4/Data/nyt_data.parquet')

# %%
df.isna().sum()
# Out:
# year       0
# title      0
# excerpt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# year       0
# title      0
# excerpt    0
# dtype: int64

# %% [markdown]
# #Subset just articles from 1970

# %%
df_1970 = df[df['year'] == 1970]
df_1970.head()
# Out:
#           year                                              title  \
# 10366505  1970  Hudson County grand jury indicts Freeholder C ...
# 10366506  1970  Bklyn Fed Ct judge says Panamanian law, not Gr...
# 10366507  1970  King Faisal arrives, Jakarta, for 3-day visit ...
# 10366508  1970  Educ Bd says virtually all substitute position...
# 10366509  1970  US preliminary defense trials Valiant Twice Ou...
#
#                                                     excerpt
# 10366505  contract later rescinded; no money changed han...
# 10366506  says generator breakdown was 'unforeseen event...
# 10366507
# 10366508  Asst Supt S Rosenberg says elimination is cond...
# 10366509

# %%
df_1970.to_csv('1970_df.csv', index=False)

# %% [markdown]
# #Subset 500 Random Rows

# %%
mini_df = df.sample(n = 500)
print(mini_df.shape)
mini_df.head()
# Out:
# (500, 3)
#           year                                              title  \
# 12497018  1987  LEAD:         *3*** COMPANY REPORTS **    *3*F...
# 16902395  2015  There has been no fighting in Western Sahara f...
# 1352909   1929  Will represent U S at 2d internatl diplomatic ...
# 15010004  2004  Nov 16 picture caption with article about incr...
# 14047149  1998  Carol J Christie letter objects to religious i...
#
#                                                     excerpt
# 12497018
# 16902395
# 1352909
# 15010004  it is Penneys, which is part of Associated Bri...
# 14047149

# %%
mini_df.to_csv('mini_df.csv', index=False)

# %%
for i in np.arange(mini_df.shape[0]):
  with open(str(i) + '.txt', 'w') as f:
    f.write(df.loc[i, 'title'])

# %% [markdown]
# #Subset 1000 rows from each decade

# %%
# Extract the decade from the 'year' column
df['decade'] = (df['year'] // 10) * 10

# Group the data by decade
grouped = df.groupby('decade')

# %%
df.head()
# Out:
#    year                                              title  \
# 0  1920  At last the Federal Reserve Board has issued r...
# 1  1920                            WILL TEST DOOR SERVICE.
# 2  1920                    Sanction for Chinese Contracts.
# 3  1920                            LEADS FRAZIER BY 4,496.
# 4  1920  CHICAGO, April 30.--With 300 suspicious charac...
#
#                                              excerpt  decade
# 0                                                       1920
# 1  Service Board to Further Examine I.R.T. Safety...    1920
# 2                                                       1920
# 3  Langer's Margin Falls in North Dakota--Gronna ...    1920
# 4  Federal Agents and Police Round-- up Suspiciou...    1920

# %%
grouped.head()
# Out:
#           year                                              title  \
# 0         1920  At last the Federal Reserve Board has issued r...
# 1         1920                            WILL TEST DOOR SERVICE.
# 2         1920                    Sanction for Chinese Contracts.
# 17301795  2020  Through two world wars, Britain’s pubs stayed ...
# 17301796  2020  NBC said that the long-running sketch variety ...
# 17301797  2020  What the next phase of the virus may look like...
# 17301798  2020  The coronavirus has infected hundreds of thous...
#
#                                                     excerpt  decade
# 0                                                              1920
# 1         Service Board to Further Examine I.R.T. Safety...    1920
# 2                                                              1920
# 3         Langer's Margin Falls in North Dakota--Gronna ...    1920
# 4         Federal Agents and Police Round-- up Suspiciou...    1920
# 1498321   Glimpse of Karolyi on Arrival Here Also Shown ...    1930
# 1498322                                                        1930
# 1498323   300 Salute Portrait of the Philanthropist at S...    1930
# 1498324   Narrow Movement on Stock Exchange--Call Money ...    1930
# 1498325   Waldron, Snead, Smith, Blake and Marlow in Fin...    1930
# 3953537                                                        1940
# 3953538                                                        1940
# 3953539                             Burrows Are Overcrowded    1940
# 3953540   Army Physician and Two Mayo Clinic Aides, as W...    1940
# 3953541   Upper Nyack Girl Will Be Bride of John Tracy W...    1940
# 6181229   A.W. Harris Charges Failure to Keep Reliable C...    1950
# 6181230   $2.30 a Share Reported Income Compares With $1...    1950
# 6181231     ON THE LOOKOUT FOR SNIPERS IN MASAN BATTLE AREA    1950
# 6181232                                                        1950
# 6181233                                                        1950
# 8444494   ' Fiorello!' Director Will Get Acre in Virgini...    1960
# 8444495                                                        1960
# 8444496                                                        1960
# 8444497   preliminary test seen about '64 WORK WILL STAR...    1960
# 8444498                                                        1960
# 10366505  contract later rescinded; no money changed han...    1970
# 10366506  says generator breakdown was 'unforeseen event...    1970
# 10366507                                                       1970
# 10366508  Asst Supt S Rosenberg says elimination is cond...    1970
# 10366509                                                       1970
# 11570377                                                       1980
# 11570378                                                       1980
# 11570379                                                       1980
# 11570380                                                       1980
# 11570381                                                       1980
# 12975250  broadcast information appears today on page 43...    1990
# 12975251                                                       1990
# 12975252                                                       1990
# 12975253                                                       1990
# 12975254                                                       1990
# 14296739                      logo (S) DEVILS DEAL FINANCED    2000
# 14296740                          Germany's Jewish Question    2000
# 14296741  Jamison, who has filled indoors and outdoors w...    2000
# 14296742                                                       2000
# 14296743                                                       2000
# 16097393                                                       2010
# 16097394                                                       2010
# 16097395                                                       2010
# 16097396                                                       2010
# 16097397                                                       2010
# 17301794                                                       2020
# 17301795                                                       2020
# 17301796                                                       2020
# 17301797                                                       2020
# 17301798                                                       2020

# %%
# Create an empty DataFrame to hold the sampled rows
decade1000_df = pd.DataFrame()

# Iterate over each decade
for decade in range(1920, 2020, 10):
    # Select 1000 random rows from the decade
    decade_rows = df.loc[(df['year'] >= decade) & (df['year'] < decade + 10)].sample(n=1000, random_state=42)
    # Add the selected rows to the sampled DataFrame
    decade1000_df = pd.concat([decade1000_df, decade_rows])

# Save the sampled DataFrame to a CSV file
decade1000_df.to_csv('decade1000_df.csv', index=False)

# %%
decade1000_df.shape
# Out:
# (10000, 4)

# %%
decade1000_df.head()
# Out:
#          year                                              title  \
# 658643   1926  A new aspirant for Tom Mix's audiences, named ...
# 311947   1922  LONDON, Jan. 30.--Ought girls to be allowed to...
# 431154   1923  J Oudegeest compares development in U S and Eu...
# 872465   1927  Statement on play by Chinese student to be pro...
# 1212106  1928           CITY COLLEGE DRILLS AGAINST R.P.I. PLAYS
#
#                                                    excerpt  decade
# 658643                                                        1920
# 311947   Discharged for Lighting Cigarette in Office, G...    1920
# 431154   sp art, with Oudegeest's por GAMPERS FAILS AS ...    1920
# 872465   " Peking Politics" Called First Effort by Nati...    1920
# 1212106  Varsity Is Nearly Scored on by Jayvees--Goldha...    1920

# %%
decade1000_df.tail()
# Out:
#           year                                              title excerpt  \
# 16843463  2014  “The Equalizer” stars Denzel Washington as a s...
# 17300839  2019  Six children were among the victims of a massa...
# 16857658  2015  The Interior Ministry said that more than 60 p...
# 16619756  2013  With significant sums about to change hands, l...
# 17148359  2017  A suspect in the attacks, Ahmed Abu Khattala, ...
#
#           decade
# 16843463    2010
# 17300839    2010
# 16857658    2010
# 16619756    2010
# 17148359    2010

# %% [markdown]
# #Combine title & exerpt into single col

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project 4/Data/decade1000_df.csv')

# %%
df2.fillna('', inplace=True)

# %%
df2['Combined_Text'] = df2['title'] + ' ' + df2['excerpt']

df2.head()
# Out:
#    year                                              title  \
# 0  1926  A new aspirant for Tom Mix's audiences, named ...
# 1  1922  LONDON, Jan. 30.--Ought girls to be allowed to...
# 2  1923  J Oudegeest compares development in U S and Eu...
# 3  1927  Statement on play by Chinese student to be pro...
# 4  1928           CITY COLLEGE DRILLS AGAINST R.P.I. PLAYS
#
#                                              excerpt  decade  \
# 0                                                       1920
# 1  Discharged for Lighting Cigarette in Office, G...    1920
# 2  sp art, with Oudegeest's por GAMPERS FAILS AS ...    1920
# 3  " Peking Politics" Called First Effort by Nati...    1920
# 4  Varsity Is Nearly Scored on by Jayvees--Goldha...    1920
#
#                                        Combined_Text
# 0  A new aspirant for Tom Mix's audiences, named ...
# 1  LONDON, Jan. 30.--Ought girls to be allowed to...
# 2  J Oudegeest compares development in U S and Eu...
# 3  Statement on play by Chinese student to be pro...
# 4  CITY COLLEGE DRILLS AGAINST R.P.I. PLAYS Varsi...

# %%
df2 = df2.drop(columns = ['title','excerpt'])
df2.head()
# Out:
#    year  decade                                      Combined_Text
# 0  1926    1920  A new aspirant for Tom Mix's audiences, named ...
# 1  1922    1920  LONDON, Jan. 30.--Ought girls to be allowed to...
# 2  1923    1920  J Oudegeest compares development in U S and Eu...
# 3  1927    1920  Statement on play by Chinese student to be pro...
# 4  1928    1920  CITY COLLEGE DRILLS AGAINST R.P.I. PLAYS Varsi...

# %%
# Save the sampled DataFrame to a CSV file
df2.to_csv('decade1000_combinedtxt.csv', index=False)

# %%
df3 = pd.read_csv('/content/decade1000_combinedtxt.csv')
