# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_parquet('/content/drive/MyDrive/IntroToDataScience-SamanthaMathieu/Project 4/Data/nyt_data.parquet')

# %%
# Convert the DataFrame to a JSON string
json_string = df.to_json(orient='records')

# Write the JSON string to a file
with open('/content/drive/MyDrive/IntroToDataScience-SamanthaMathieu/Project 4/Data', 'w') as f:
    f.write(json_string)
